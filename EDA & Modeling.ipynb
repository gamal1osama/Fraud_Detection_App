# %% [markdown]
# # Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import joblib


import warnings
warnings.filterwarnings('ignore')

plt.style.use('dark_background')

sns.set_style("darkgrid", {
    'axes.facecolor': '#111111',
    'figure.facecolor': '#111111',
    'axes.edgecolor': '#444444',
    'grid.color': '#333333',
    'text.color': 'white',
    'xtick.color': 'white',
    'ytick.color': 'white',
    'axes.labelcolor': 'white',
    'axes.grid': True,
})

# %% [markdown]
# # Get Data

# %%
df = pd.read_csv("AIML Dataset.csv")

# %%
df.sample(5)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 1217040   133   PAYMENT   10513.18  C1069752782           0.00
# 2332586   188   CASH_IN  264748.74   C458125472    17635453.44
# 5158465   357   PAYMENT    5746.92  C1711776687           0.00
# 820873     40  CASH_OUT  347636.14   C375591972         758.00
# 3186234   239  CASH_OUT   70729.52   C204880773           0.00
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 1217040            0.00   M616481506            0.00            0.00        0
# 2332586     17900202.18   C535680620       419898.84       155150.10        0
# 5158465            0.00  M1253615895            0.00            0.00        0
# 820873             0.00   C907600353       319901.29       667537.43        0
# 3186234            0.00   C393843232       351918.16       422647.69        0
#
#          isFlaggedFraud
# 1217040               0
# 2332586               0
# 5158465               0
# 820873                0
# 3186234               0

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.describe().T
# Out:
#                     count          mean           std  min       25%  \
# step            6362620.0  2.433972e+02  1.423320e+02  1.0    156.00
# amount          6362620.0  1.798619e+05  6.038582e+05  0.0  13389.57
# oldbalanceOrg   6362620.0  8.338831e+05  2.888243e+06  0.0      0.00
# newbalanceOrig  6362620.0  8.551137e+05  2.924049e+06  0.0      0.00
# oldbalanceDest  6362620.0  1.100702e+06  3.399180e+06  0.0      0.00
# newbalanceDest  6362620.0  1.224996e+06  3.674129e+06  0.0      0.00
# isFraud         6362620.0  1.290820e-03  3.590480e-02  0.0      0.00
# isFlaggedFraud  6362620.0  2.514687e-06  1.585775e-03  0.0      0.00
#
#                        50%           75%           max
# step               239.000  3.350000e+02  7.430000e+02
# amount           74871.940  2.087215e+05  9.244552e+07
# oldbalanceOrg    14208.000  1.073152e+05  5.958504e+07
# newbalanceOrig       0.000  1.442584e+05  4.958504e+07
# oldbalanceDest  132705.665  9.430367e+05  3.560159e+08
# newbalanceDest  214661.440  1.111909e+06  3.561793e+08
# isFraud              0.000  0.000000e+00  1.000000e+00
# isFlaggedFraud       0.000  0.000000e+00  1.000000e+00

# %%
df.describe(include='object').T
# Out:
#             count   unique          top     freq
# type      6362620        5     CASH_OUT  2237500
# nameOrig  6362620  6353307  C1677795071        3
# nameDest  6362620  2722362  C1286084959      113

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
list(df.columns)
# Out:
# ['step',
#  'type',
#  'amount',
#  'nameOrig',
#  'oldbalanceOrg',
#  'newbalanceOrig',
#  'nameDest',
#  'oldbalanceDest',
#  'newbalanceDest',
#  'isFraud',
#  'isFlaggedFraud']

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# # EDA

# %%
round((df['isFraud'].value_counts()[1]/df.shape[0])*100, 3) # there is a class impalance
# Out:
# np.float64(0.129)

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
type_counts = df['type'].value_counts()

plt.bar(type_counts.index, type_counts.values)
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.title('Distribution of Types')
plt.xticks(rotation=45) 
plt.tight_layout()
plt.show()

# %%
fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_type
# Out:
# type
# TRANSFER    0.007688
# CASH_OUT    0.001840
# CASH_IN     0.000000
# DEBIT       0.000000
# PAYMENT     0.000000
# Name: isFraud, dtype: float64

# %%
plt.bar(fraud_by_type.index, fraud_by_type.values)
plt.xlabel('Types')
plt.ylabel('Mean')
plt.title('Fraud By Type')
plt.xticks(rotation=45) 
plt.tight_layout()
plt.show()

# %%
df['amount'].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
df['amount'].median()
# Out:
# np.float64(74871.94)

# %%
sns.histplot(df['amount'], bins = 100, kde = True)
plt.title("distribution before log scaled ")
plt.xlabel("Amount")
plt.show()

# %%
sns.histplot(np.log1p(df['amount']), bins = 100, kde = True)
plt.title("distribution after log scaled ")
plt.xlabel("Log( 1 + Amount)")
plt.show()

# %%
sns.boxplot(data = df[df['amount'] < 70000], x = 'isFraud', y = 'amount')
plt.title("Amount vs Fraud (Filtered below 70000)")
plt.show()

# %%
df['balanceDiffOrig'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['balanceDiffDest'] = df['oldbalanceDest'] - df['newbalanceDest']

# %%
frauds_per_Step = df[df['isFraud'] == 1]['step'].value_counts().sort_index()

plt.plot(frauds_per_Step.index, frauds_per_Step.values, label = "fraud per step")
plt.title("Frauds over time")
plt.xlabel("Step (Time)")
plt.ylabel("Number of frauds")
plt.grid(True)
plt.show()
# we gain that it is time independent so let's drop it

# %%
df.drop(columns = 'step', inplace=True)

# %%
top_senders = df['nameOrig'].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C1677795071    3
# C1999539787    3
# C724452879     3
# C1976208114    3
# C400299098     3
# C1784010646    3
# C1530544995    3
# C1065307291    3
# C545315117     3
# C1902386530    3
# Name: count, dtype: int64

# %%
top_recievers = df['nameDest'].value_counts().head(10)
top_recievers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C1789550256     99
# C451111351      99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df['isFraud'] == 1]['nameDest'].value_counts().head(10)
fraud_users
# Out:
# nameDest
# C967226405     2
# C1601170327    2
# C650699445     2
# C105660024     2
# C1981613973    2
# C803116137     2
# C505532836     2
# C964377943     2
# C200064275     2
# C1259079602    2
# Name: count, dtype: int64

# %%
transfer_and_cash_out_df = df[df['type'].isin(['TRANSFER', 'CASH_OUT'])]

# %%
transfer_and_cash_out_df['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data = transfer_and_cash_out_df, x ='type', hue = 'isFraud')
plt.title("Fraud Distribution by Types (TRANSFER and CASH_OUT)")
plt.show()

# %%
corr = df[['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest', 'isFraud']].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
zero_after_transfer = df[
    (df['oldbalanceOrg'] > 0) & 
    (df['newbalanceOrig'] == 0) &
    (df['type'].isin(['TRANSFER', 'CASH_OUT']))
]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.sample(5)
# Out:
#              type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 3634732  CASH_OUT  153997.00   C749919106         700.00             0.0
# 2852921  TRANSFER  341409.99   C327169833       39161.00             0.0
# 6016203  CASH_OUT  157651.39  C1991645335       83898.84             0.0
# 3371727  CASH_OUT  389535.57  C1650177456        5061.00             0.0
# 2292199  CASH_OUT  168324.06   C960566790       15794.00             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 3634732   C805749445      6748119.08      6902116.08        0               0
# 2852921   C756990538            0.00       341409.99        0               0
# 6016203  C1570303600      8301050.11      8458701.49        0               0
# 3371727   C374923014        60207.17       449742.74        0               0
# 2292199   C114447398      1023617.37      1191941.42        0               0
#
#          balanceDiffOrig  balanceDiffDest
# 3634732           700.00       -153997.00
# 2852921         39161.00       -341409.99
# 6016203         83898.84       -157651.38
# 3371727          5061.00       -389535.57
# 2292199         15794.00       -168324.05

# %% [markdown]
# # Modeling

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# 2           181.00              0.0
# 3           181.00          21182.0
# 4         11668.14              0.0

# %%
df_modeling = df.drop(columns=['nameOrig', 'nameDest', 'isFlaggedFraud'])

# %%
df_modeling.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrig  balanceDiffDest
# 0             0.0        0          9839.64              0.0
# 1             0.0        0          1864.28              0.0
# 2             0.0        1           181.00              0.0
# 3             0.0        1           181.00          21182.0
# 4             0.0        0         11668.14              0.0

# %%
cat = ['type']
num = ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']

# %%
x = df_modeling.drop(columns='isFraud')
y = df_modeling['isFraud']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num),
        ('cat', OneHotEncoder(), cat)
    ]
)

# %%
pipeline  = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000, random_state=42, class_weight='balanced'))
])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['type'])])),
#                 ('classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
ypred = pipeline.predict(x_test)

# %%
print(classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
pipeline.score(x_test, y_test)
# Out:
# 0.9467064406381858

# %%
joblib.dump(pipeline, 'fraud_detection_model.pkl')
# Out:
# ['fraud_detection_model.pkl']
